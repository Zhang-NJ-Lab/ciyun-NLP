# %%
from nltk import data
#data.path.append(r'../nltk_data')

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from nltk import word_tokenize

# %%
from nltk.stem import WordNetLemmatizer

# %%
import nltk

# %%
from collections import Counter

# %%
import re

# %%
import matplotlib as mpl

# %%
mpl.rcParams['figure.dpi'] = 300

# %%
text = open('./data/text_corpus.txt', 'r').read()

# %%
text[:1000]
# Out:
# 'Lei Zhang is a full-time professor at the Nanjing University of Information Science and Technology (NUIST). He obtained his PhD degree in Natural Science (Physics) from Cavendish Laboratory, University of Cambridge. Prior to this, he received his MSc in Composite Materials from Imperial College London, and His BEng degree from Nanyang Technological University, Singapore. Before joining NUIST, he is a post-doc at the State University of New York at Buffalo. \n\nHis research interests include materials informatics, photovoltaic materials, energy materials, optoelectronic materials and computational materials science. Recently, he is focusing on the development and application of natural language processing (NLP) and other data-driven methods combined with first-principles calculations to predict and understand photovoltaic materials and beyond.\n\nHe has published >100 scientific papers in SCI journals such as Nano Energy and Advanced Functional Materials. He has refereed hundreds of manuscr'

# %%
def lemmatize_and_clean(text):
    nltk.download('wordnet')
    nltk.download('omw-1.4')
    nltk.download('punkt')
    lemmatizer = WordNetLemmatizer()
    cleaned_lemmatized_tokens = [lemmatizer.lemmatize(word.lower()) \
                                 for word in word_tokenize(re.sub(r'([^\s\w]|_)+', ' ', text))]
    return cleaned_lemmatized_tokens

# %%
Counter(lemmatize_and_clean(text)).most_common(50)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     D:\ProgramData\Anaconda3\envs\py37\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     D:\ProgramData\Anaconda3\envs\py37\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     D:\ProgramData\Anaconda3\envs\py37\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [('of', 22),
#  ('material', 21),
#  ('and', 17),
#  ('science', 10),
#  ('journal', 10),
#  ('university', 9),
#  ('chemistry', 7),
#  ('he', 6),
#  ('physic', 6),
#  ('information', 5),
#  ('natural', 5),
#  ('a', 4),
#  ('the', 4),
#  ('nanjing', 4),
#  ('technology', 4),
#  ('his', 4),
#  ('physical', 4),
#  ('is', 3),
#  ('professor', 3),
#  ('at', 3),
#  ('in', 3),
#  ('from', 3),
#  ('state', 3),
#  ('research', 3),
#  ('energy', 3),
#  ('optoelectronic', 3),
#  ('language', 3),
#  ('processing', 3),
#  ('nano', 3),
#  ('chemical', 3),
#  ('solar', 3),
#  ('cell', 3),
#  ('engineering', 3),
#  ('school', 3),
#  ('nuist', 2),
#  ('phd', 2),
#  ('degree', 2),
#  ('cavendish', 2),
#  ('laboratory', 2),
#  ('cambridge', 2),
#  ('to', 2),
#  ('msc', 2),
#  ('composite', 2),
#  ('imperial', 2),
#  ('college', 2),
#  ('london', 2),
#  ('nanyang', 2),
#  ('technological', 2),
#  ('new', 2),
#  ('york', 2)]

# %%
cleaned_text = ' '.join(lemmatize_and_clean(text))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     D:\ProgramData\Anaconda3\envs\py37\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     D:\ProgramData\Anaconda3\envs\py37\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     D:\ProgramData\Anaconda3\envs\py37\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
cleaned_text
# Out:
# 'lei zhang is a full time professor at the nanjing university of information science and technology nuist he obtained his phd degree in natural science physic from cavendish laboratory university of cambridge prior to this he received his msc in composite material from imperial college london and his beng degree from nanyang technological university singapore before joining nuist he is a post doc at the state university of new york at buffalo his research interest include material informatics photovoltaic material energy material optoelectronic material and computational material science recently he is focusing on the development and application of natural language processing nlp and other data driven method combined with first principle calculation to predict and understand photovoltaic material and beyond he ha published 100 scientific paper in sci journal such a nano energy and advanced functional material he ha refereed hundred of manuscript for journal including journal of the american chemical society jacs matter ac nano npj computational material journal of chemical information and modelling journal of physical chemistry letter journal of physical chemistry c ac applied material interface journal of material chemistry a journal of material chemistry c nano research journal of power source advanced electronic material journal of power source nanoscale physical chemistry chemical physic solar engergy material and solar cell cell report physical science etc education 2010 2014 university of cambridge cavendish laboratory phd natural science physic 2009 2010 imperial college london composite centre msc 2005 2009 nanyang technological university material science and engineering b eng work experience 2019 now nanjing university of information science and technology school of chemistry and material science professor 2017 2019 nanjing university of information science and technology school of physic and optoelectronic engineering professor 2015 2017 nanjing university of information science and technology school of physic and optoelectronic engineering lecturer 2014 2015 state univeristy of new york buffalo department of chemistry postdoctoral research scientist reserch area material informatics natural language processing solar cell material energy material method data driven natural language processing machine learning first principle calculation photoelectrochemical experiment teaching solid state physic material frontier material english'

# %%
stopwords = set(STOPWORDS)

# %%
wordcloud = WordCloud(width = 800, height = 800,
                      background_color='white',
                      max_words=50,
                      stopwords = stopwords,
                      min_font_size = 10).generate(cleaned_text)

# %%
plt.imshow(wordcloud, interpolation= 'bilinear')
plt.axis("off")
plt.savefig('张磊词云.jpg',dpi=500, bbox_inches='tight')
plt.show()
